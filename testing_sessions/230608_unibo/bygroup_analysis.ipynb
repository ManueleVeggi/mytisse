# %% [markdown]
# ## MyTISSE. Group Analysis.
#
# The following Jupyter Notebook provides an analysis of the results of the testing session.
#
# The methods and algortihms used in the [Exploratory analysis](exploratory_analysis.ipynb) have been collected in more generic function in a general Python [script](analysis_methods.py), which is imported in the current Jupyter Notebook
#
# ### Table of Contents
# * [Perception of meaningfulness](#h3meaning)
#     * [Summarization task](#h4sumup)
#     * [Meaningfulness factors](#h4m_fact)
# * [Choice of the palette](#h3palette)
#     * [Justification](#h4palettejust)
# * [Emotional engagement](#h3emotion)
#     * [Feelings](#h4emotion)
#     * [Caring attitude](#h4care)
#         * [Loss](#h5care_1)
#         * [Perceived benefit](#h5care_2)

# %%
from analysis_methods import *

mytisse_data = pd.read_csv("data/data_cleaned.csv", sep=";")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/manuele/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Perception of meaningfulness <a class="anchor" id="h3meaning"></a>
#
# #### Summarization task <a class="anchor" id="h4sumup"></a>

# %%
groupA = mytisse_data[mytisse_data['group_id'] == 'A']
groupB = mytisse_data[mytisse_data['group_id'] == 'B']
groupC = mytisse_data[mytisse_data['group_id'] == 'C']

print("Group A")
return_topwords(topwords_calculator(groupA.q1), 3)
print("\n", "Group B")
return_topwords(topwords_calculator(groupB.q1), 3)
print("\n", "Group C")
return_topwords(topwords_calculator(groupC.q1), 3)
# Out:
# Group A
# color :  8
# interesting :  5
# figure :  5
# painting :  5
# work :  3
# different :  3
#
#  Group B
# painting :  11
# figure :  4
# shape :  4
# work :  4
# palette :  3
# color :  3
# look :  3
#
#  Group C
# painting :  5
# figure :  4
# color :  4
# interesting :  3
# artistic :  3

# %% [markdown]
# #### Meaningfulness factors <a class="anchor" id="h4m_fact"></a>

# %%
print("Group A")
meaningfulness_factor_plot(groupA)
print("Group B")
meaningfulness_factor_plot(groupB)
print("Group C")
meaningfulness_factor_plot(groupC)
# Out:
# Group A
# Group B
# Group C

# %% [markdown]
# ### The choice of the palette <a class="anchor" id="h3palette"></a>

# %%
pie_viz(groupA, "q3", "A] During the experience  two colors palettes have been proposed. Which one did you choose?")
pie_viz(groupB, "q3", "B] During the experience  two colors palettes have been proposed. Which one did you choose?")
pie_viz(groupC, "q3", "C] During the experience  two colors palettes have been proposed. Which one did you choose?")
# Out:
# Palette A    8
# Name: q3, dtype: int64
# Palette B    6
# Palette A    2
# Name: q3, dtype: int64
# Palette A    6
# Palette B    2
# Name: q3, dtype: int64

# %% [markdown]
# #### Justification <a class="anchor" id="h4palettejust"></a>

# %%
gB_palette_a = groupB[groupB['q3'] == 'Palette A']['q3_justification']
gB_palette_a = groupB[groupB['q3'] == 'Palette A']['q3_justification']

print("GROUP A", "\n", "Palette A")
return_topwords(topwords_calculator(groupA[groupA['q3'] == 'Palette A']['q3_justification']), 2)

print("\n", "GROUP B", "\n", "Palette A")
return_topwords(topwords_calculator(groupB[groupB['q3'] == 'Palette A']['q3_justification']), 2)
print(" Palette B")
return_topwords(topwords_calculator(groupB[groupB['q3'] == 'Palette B']['q3_justification']), 2)

print("\n", "GROUP C", "\n", "Palette A")
return_topwords(topwords_calculator(groupC[groupC['q3'] == 'Palette A']['q3_justification']), 2)
print(" Palette B")
return_topwords(topwords_calculator(groupC[groupC['q3'] == 'Palette B']['q3_justification']), 2)
# Out:
# GROUP A
#  Palette A
# color :  5
# vibrant :  4
# palette :  4
# associate :  2
# emotion :  2
# first :  2
# remember :  2
# it’s :  2
# figure :  2
# painting :  2
#
#  GROUP B
#  Palette A
# color :  3
# title :  2
#  Palette B
# color :  5
# painting :  4
# chose :  3
# subject :  2
# palette :  2
# eye :  2
# also :  2
#
#  GROUP C
#  Palette A
# color :  5
# tone :  3
# figure :  3
# time :  2
# felt :  2
# human :  2
# seemed :  2
# light :  2
# one :  2
# palette :  2
#  Palette B
# color :  2

# %% [markdown]
# ### Emotional engagement <a class="anchor" id="h3emotion"></a>
#
# The visualization through the library pyplutchick is available at the following [Jupyter Notebook](https://github.com/ManueleVeggi/mytisse/blob/main/testing_sessions/230608_unibo/plutchick_emotions.ipynb).
#
# #### Feelings <a class="anchor" id="h4emotion"></a>

# %%
pie_viz(groupA, "q9", 'A] Have you ever studied the Parisian artistic context in the between 19th and 20th century?')
pie_viz(groupB, "q9", 'B] Have you ever studied the Parisian artistic context in the between 19th and 20th century?')
pie_viz(groupC, "q9", 'C] Have you ever studied the Parisian artistic context in the between 19th and 20th century?')
# Out:
# Yes, in high school    4
# No                     3
# Yes, at university     1
# Name: q9, dtype: int64
# Yes, in high school    4
# Yes, at university     3
# No                     1
# Name: q9, dtype: int64
# Yes, in high school       4
# Yes, at university        2
# Yes, in other contexts    1
# No                        1
# Name: q9, dtype: int64

# %%
emotion_plot(emotion_data(groupA, "q4"), "A] Which are the feelings you associate with 'Bathers by a River'")
emotion_plot(emotion_data(groupB, "q4"), "B] Which are the feelings you associate with 'Bathers by a River'")
emotion_plot(emotion_data(groupC, "q4"), "C] Which are the feelings you associate with 'Bathers by a River'")

print("EDIT VERSION NO. 1 ================")
emotion_plot(emotion_data(groupA,"q10"), "A] Which are the feelings you associate with this painting (1)")
emotion_plot(emotion_data(groupB,"q10"), "B] Which are the feelings you associate with this painting (1)")
emotion_plot(emotion_data(groupC,"q10"), "C] Which are the feelings you associate with this painting (1)")

print("EDIT VERSION NO. 2 ================")
emotion_plot(emotion_data(groupA,"q12"), "A] Which are the feelings you associate with this painting (2)")
emotion_plot(emotion_data(groupB,"q12"), "B] Which are the feelings you associate with this painting (2)")
emotion_plot(emotion_data(groupC,"q12"), "C] Which are the feelings you associate with this painting (2)")
# Out:
# EDIT VERSION NO. 1 ================
# posx and posy should be finite values
# EDIT VERSION NO. 2 ================
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
print("Group A", "\n", emotion_barcomparison(groupA))
print("Group B", "\n", emotion_barcomparison(groupB))
print("Group C", "\n", emotion_barcomparison(groupC))
# Out:
# Group A
#                Original  Edit 1  Edit 2
# anger             1.50    1.75    1.12
# disgust           1.38    1.25    1.00
# fear              2.75    1.25    2.88
# anticipation      2.00    2.75    3.50
# joy               2.12    2.75    1.62
# sadness           3.75    1.25    2.25
# surprise          1.25    2.88    3.12
# trust             2.12    2.25     NaN
# Group B
#                Original  Edit 1  Edit 2
# anger             2.00    2.38    2.12
# disgust           1.88    2.38    1.88
# fear              2.75    2.88    3.00
# anticipation      2.75    2.38    3.38
# joy               1.88    2.38    2.12
# sadness           3.50    2.12    3.00
# surprise          2.12    3.50    2.38
# trust             3.00    1.88     NaN
# Group C
#                Original  Edit 1  Edit 2
# anger             1.88    2.31    1.50
# disgust           1.62    1.88    1.50
# fear              2.62    2.00    3.75
# anticipation      3.50    3.12    4.25
# ...

# %% [markdown]
# #### Caring attitude <a class="anchor" id="h4care"></a>
#
# Loss (Q5) <a class="anchor" id="h5care_1"></a>

# %%
pie_viz(groupA, "q5", "A] How much would you be sorry for this loss?")
pie_viz(groupB, "q5", "B] How much would you be sorry for this loss?")
pie_viz(groupC, "q5", "C] How much would you be sorry for this loss?")
# Out:
# 5    4
# 4    4
# Name: q5, dtype: int64
# 4    5
# 5    3
# Name: q5, dtype: int64
# 5    6
# 4    2
# Name: q5, dtype: int64

# %% [markdown]
# Perceived benefit (Q6) <a class="anchor" id="h5care_2"></a>

# %%
no_occurrencesA = no_benefit(groupA)
return_topwords(topwords_calculator(groupA['q6']), 3)

no_occurrencesB = no_benefit(groupB)
return_topwords(topwords_calculator(groupA['q6']), 3)

no_occurrencesC = no_benefit(groupC)
return_topwords(topwords_calculator(groupC['q6']), 3)
# Out:
# Approximative amount of participants who denied any benefit:  5
# helped :  3
# way :  3
# painting :  3
# Approximative amount of participants who denied any benefit:  1
# helped :  3
# way :  3
# painting :  3
# Approximative amount of participants who denied any benefit:  2
# helped :  4
# painting :  4
# think :  3
# color :  3
# art :  3
# thinking :  3
